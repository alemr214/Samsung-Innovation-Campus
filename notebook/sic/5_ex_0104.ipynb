# %% [markdown]
# # Coding Exercise #0104

# %% [markdown]
# ### 1. Pandas Series:

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### 1.1. Creating Series objects:

# %%
my_index = ['a','b','c']
my_values = [222,333,444]
my_dict = {'a':222, 'b':333, 'c':444}
my_arr = np.array(my_values)

# %%
# Series with values.
pd.Series(my_values)
# Out:
# 0    222
# 1    333
# 2    444
# dtype: int64

# %%
# Series with values and index labels.
pd.Series(data=my_values, index=my_index)
# Out:
# a    222
# b    333
# c    444
# dtype: int64

# %%
# Series from a NumPy array.
pd.Series(my_arr)
# Out:
# 0    222
# 1    333
# 2    444
# dtype: int64

# %%
# Series from a NumPy array with index labels.
pd.Series(my_arr, index=my_index)
# Out:
# a    222
# b    333
# c    444
# dtype: int64

# %%
# Series from a dictionary.
pd.Series(my_dict)
# Out:
# a    222
# b    333
# c    444
# dtype: int64

# %% [markdown]
# #### 1.2. Series attributes and indexing:
#
# > Agregar bloque entrecomillado

# %%
s = pd.Series(data=[111,222,333,444], index = ['a','b','c','d'], name='MySeries')
s
# Out:
# a    111
# b    222
# c    333
# d    444
# Name: MySeries, dtype: int64

# %% [markdown]
# Series attributes:

# %%
s.index                                   # Index labels.
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
s.name                                    # Name attribute.
# Out:
# 'MySeries'

# %%
s.dtype                                   # Data type.
# Out:
# dtype('int64')

# %%
s.values                                  # The values as NumPy array.
# Out:
# array([111, 222, 333, 444])

# %% [markdown]
# Series indexing and slicing:

# %%
s[1]
# Out:
# <ipython-input-13-f8bb2b116405>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s[1]
# 222

# %%
s.iloc[1] #esta es la forma correcta de acceder al valor de la serie.
# Out:
# 222

# %%
s['a']
# Out:
# 111

# %%
s[2:3] #EXCLUIDO EL 3
# Out:
# c    333
# Name: MySeries, dtype: int64

# %%
s[2:4] #INCLUIDO EL 4
# Out:
# c    333
# d    444
# Name: MySeries, dtype: int64

# %%
s
# Out:
# a    111
# b    222
# c    333
# d    444
# Name: MySeries, dtype: int64

# %%
s[['a','d']]
# Out:
# a    111
# d    444
# Name: MySeries, dtype: int64

# %% [markdown]
# #### 1.3. Series operations:

# %%
s1 = pd.Series(data=[1,2,3,4], index = ['d','b','c','a'])
s2 = pd.Series(data=[1,2,3,4], index = ['a','b','d','e'])

# %%
s1
# Out:
# d    1
# b    2
# c    3
# a    4
# dtype: int64

# %%
s2
# Out:
# a    1
# b    2
# d    3
# e    4
# dtype: int64

# %% [markdown]
# Please notice that in the Series to Series operations, the elements are matched by the index labels. <br>
# When there is no mathing index label, we get **NaN**.

# %%
s1 + s2
# Out:
# a    5.0
# b    4.0
# c    NaN
# d    4.0
# e    NaN
# dtype: float64

# %%
s1 - s2
# Out:
# a    3.0
# b    0.0
# c    NaN
# d   -2.0
# e    NaN
# dtype: float64

# %%
s1 * s2
# Out:
# a    4.0
# b    4.0
# c    NaN
# d    3.0
# e    NaN
# dtype: float64

# %%
s1/s2
# Out:
# a    4.000000
# b    1.000000
# c         NaN
# d    0.333333
# e         NaN
# dtype: float64

# %%
2*s1
# Out:
# d    2
# b    4
# c    6
# a    8
# dtype: int64

# %% [markdown]
# #### 1.4. Series methods:

# %%
s1
# Out:
# d    1
# b    2
# c    3
# a    4
# dtype: int64

# %%
s2
# Out:
# a    1
# b    2
# d    3
# e    4
# dtype: int64

# %%
s1.sum()
# Out:
# 10

# %%
s1.mean()
# Out:
# 2.5

# %%
s1.median()
# Out:
# 2.5

# %%
s1.max()
# Out:
# 4

# %%
s1.std()
# Out:
# 1.2909944487358056

# %%
s1.sort_values()
# Out:
# d    1
# b    2
# c    3
# a    4
# dtype: int64

# %%
s1.sort_index()
# Out:
# a    4
# b    2
# c    3
# d    1
# dtype: int64

# %% [markdown]
# apply() method:

# %%
ser_height = pd.Series([165.3, 170.1, 175.0, 182.1, 168.0, 162.0, 155.2, 176.9, 178.5, 176.1,
                        167.1, 180.0, 162.2, 176.1, 158.2, 168.6, 169.2],name='height')
ser_height
# Out:
# 0     165.3
# 1     170.1
# 2     175.0
# 3     182.1
# 4     168.0
# 5     162.0
# 6     155.2
# 7     176.9
# 8     178.5
# 9     176.1
# 10    167.1
# 11    180.0
# 12    162.2
# 13    176.1
# 14    158.2
# 15    168.6
# 16    169.2
# Name: height, dtype: float64

# %%
ser_height.apply(lambda x: x/100) #lambda crea una función anónima (una función sin nombre).
                                  #x es el parámetro de entrada de la función. Se refiere a cada valor individual dentro de la Serie ser_height.
# Out:
# 0     1.653
# 1     1.701
# 2     1.750
# 3     1.821
# 4     1.680
# 5     1.620
# 6     1.552
# 7     1.769
# 8     1.785
# 9     1.761
# 10    1.671
# 11    1.800
# 12    1.622
# 13    1.761
# 14    1.582
# 15    1.686
# 16    1.692
# Name: height, dtype: float64

# %%
heights_in_meters = ser_height / 100
heights_in_meters
# Out:
# 0     1.653
# 1     1.701
# 2     1.750
# 3     1.821
# 4     1.680
# 5     1.620
# 6     1.552
# 7     1.769
# 8     1.785
# 9     1.761
# 10    1.671
# 11    1.800
# 12    1.622
# 13    1.761
# 14    1.582
# 15    1.686
# 16    1.692
# Name: height, dtype: float64

# %%
height_category = ser_height.apply(lambda x: 'Alto' if x > 170 else 'Bajo')
print(height_category)
# Out:
# 0     Bajo
# 1     Alto
# 2     Alto
# 3     Alto
# 4     Bajo
# 5     Bajo
# 6     Bajo
# 7     Alto
# 8     Alto
# 9     Alto
# 10    Bajo
# 11    Alto
# 12    Bajo
# 13    Alto
# 14    Bajo
# 15    Bajo
# 16    Bajo
# Name: height, dtype: object

# %% [markdown]
# Create a series of objects from Python dictionary objects.

# %%
sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
obj1 = pd.Series(sdata)
obj1
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %% [markdown]
# When creating a series of objects with only dictionary objects, the key values of dictionaries enter in order. You can also index them yourself.

# %%
states = ['California', 'Ohio', 'Oregon', 'Texas']
obj2 = pd.Series(sdata, index=states)
obj2
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %% [markdown]
# Only three of the values in sdata in this example can be checked, because the values for 'California' cannot be found. This value is denoted as NaN(not a number), and is treated as a missing value or NA value in pandas. 'Utah' is not included in the states, so it is excluded from the execution result.

# %% [markdown]
# inull and notnull functions are used to find missing data.

# %%
pd.isnull(obj2)
# Out:
# state
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# Name: population, dtype: bool

# %%
pd.notnull(obj2)
# Out:
# state
# California    False
# Ohio           True
# Oregon         True
# Texas          True
# Name: population, dtype: bool

# %% [markdown]
# This method also exists as an instance method of the series.

# %%
obj2.isnull()
# Out:
# state
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# Name: population, dtype: bool

# %% [markdown]
# A useful function of the series is automatic aligning with indeces and labels in arithmetic operations.

# %%
obj1
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
obj2
# Out:
# state
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# Name: population, dtype: float64

# %%
obj1 + obj2
# Out:
# California         NaN
# Ohio           70000.0
# Oregon         32000.0
# Texas         142000.0
# Utah               NaN
# dtype: float64

# %% [markdown]
# Both the series object and the series index have a name attribute, which is closely related to the core function of pandas.

# %%
obj2.name = 'population'
obj2.index.name = 'state'
obj2
# Out:
# state
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# Name: population, dtype: float64

# %%
# Convertir la Serie en un DataFrame
df = obj2.reset_index()
                            # convierte una Serie (obj2) en un DataFrame y restablece su índice para que las etiquetas de
                            # índice actuales se conviertan en una columna del DataFrame.
# Imprimir el DataFrame
print(df)
# Out:
#         state  population
# 0  California         NaN
# 1        Ohio     35000.0
# 2      Oregon     16000.0
# 3       Texas     71000.0

# %% [markdown]
# The index of the series can be changed through substitution.

# %%
obj1
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
obj1.index = ['Bob', 'Steve', 'Jeff', 'Ryan']
obj1
# Out:
# Bob      35000
# Steve    71000
# Jeff     16000
# Ryan      5000
# dtype: int64
